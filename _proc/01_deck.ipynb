# %% [raw]
# ---
# description: A deck of playing cards
# output-file: deck.html
# title: deck
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(Deck)
# Out:
# ---
#
# [source](https://github.com/blue-eagle/nbdev_test2/blob/master/nbdev_test2/deck.py#L11){target="_blank" style="float:right; font-size:smaller"}
#
# ### Deck
#
# >      Deck ()
#
# A deck of 52 cards, not including jokers

# %%
deck = Deck()

# %% [markdown]
# That should be 52 cards

# %%
test_eq(len(deck), 52)

# %% [markdown]
# As a reminder, these are the suits we define for a [`Card`](https://blue-eagle.github.io/nbdev-test2/card.html#card):

# %%
suits
# Out:
# '♣♦♥♠'

# %%
Card(1,1) in deck
# Out:
# False

# %%
#|output: asis
#| echo: false
show_doc(Deck.remove)
# Out:
# ---
#
# [source](https://github.com/blue-eagle/nbdev_test2/blob/master/nbdev_test2/deck.py#L26){target="_blank" style="float:right; font-size:smaller"}
#
# ### Deck.remove
#
# >      Deck.remove (card:nbdev_test2.card.Card)
#
# Removes `card` from the deck or raises exception if it is not there
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | card | Card | Card to remove |

# %%
#|output: asis
#| echo: false
show_doc(Deck.pop)
# Out:
# ---
#
# [source](https://github.com/blue-eagle/nbdev_test2/blob/master/nbdev_test2/deck.py#L21){target="_blank" style="float:right; font-size:smaller"}
#
# ### Deck.pop
#
# >      Deck.pop (idx:int=-1)
#
# remove one card from the deck
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | idx | int | -1 | the index of the card to remove, defaulting to the last one |

# %%
deck = Deck()
deck.pop()
# Out:
# K♠

# %%
test_eq(len(deck), 51)
